# %% [markdown]
# ### Import packages

# %%
import numpy as np
import pandas as pd
import requests as requests
from io import StringIO
import csv
import os
from datetime import datetime
import pytz
from time import time
import matplotlib.pyplot as plt

# %% [markdown]
# ### Prepering raw dataset for analysis
# #### All information about dataset you can find in [README.MD](https://github.com/MSI17819/Berlin_bike_theft_prediction/blob/main/README.md) file

# %% [markdown]
# #### Create empty dataframe

# %%
df = pd.DataFrame()

# %% [markdown]
# #### Data pulling function from url adress, where we can find data about Berlin bikes thief record from 01/01/2021-up to today.
# #### The data are updated everyday or at least once a two/three day, so when we run function the data are expanding on new records.

# %%
def data_pulling_function():
    global df
    url = "https://www.internetwache-polizei-berlin.de/vdb/Fahrraddiebstahl.csv"
    response = requests.get(url)
    df_raw = pd.read_csv(StringIO(response.text))
    local_time = datetime.now(pytz.timezone('Europe/Warsaw'))
    df = df.append(df_raw)
    pd.set_option('display.max_columns', None)
    print('Data update - {}'.format(local_time.strftime("%Y-%m-%d %H:%M:%S")))
    return df

data_pulling_function()
# Out:
# Data update - 2022-08-11 21:47:16
# C:\Users\dell\AppData\Local\Temp/ipykernel_9736/789137709.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_raw)
#       ANGELEGT_AM TATZEIT_ANFANG_DATUM  TATZEIT_ANFANG_STUNDE  \
# 0      10.08.2022           10.08.2022                      0
# 1      10.08.2022           09.08.2022                     15
# 2      10.08.2022           09.08.2022                     15
# 3      10.08.2022           08.08.2022                     20
# 4      10.08.2022           09.08.2022                     14
# ...           ...                  ...                    ...
# 32595  02.01.2021           01.01.2021                     12
# 32596  01.01.2021           01.01.2021                      5
# 32597  01.01.2021           01.01.2021                     17
# 32598  01.01.2021           01.01.2021                     20
# 32599  01.01.2021           01.01.2021                      9
#
#       TATZEIT_ENDE_DATUM  TATZEIT_ENDE_STUNDE       LOR  SCHADENSHOEHE  \
# 0             10.08.2022                    0   3400619            300
# 1             10.08.2022                    0   7601544            800
# 2             10.08.2022                    6   5100211            212
# 3             09.08.2022                   12   3601449            600
# 4             09.08.2022                   14   3601450            499
# ...                  ...                  ...       ...            ...
# 32595         02.01.2021                   15  11300826            377
# 32596         01.01.2021                    8  10400941           2527
# 32597         01.01.2021                   18   8401241            888
# 32598         01.01.2021                   20   2100104           2800
# 32599         01.01.2021                   11   4200206            290
#
#       VERSUCH   ART_DES_FAHRRADS                     DELIKT  \
# 0        Nein       Mountainbike           Fahrraddiebstahl
# 1        Nein      Herrenfahrrad           Fahrraddiebstahl
# 2        Nein      Herrenfahrrad           Fahrraddiebstahl
# 3        Nein       Damenfahrrad           Fahrraddiebstahl
# 4        Nein      Herrenfahrrad           Fahrraddiebstahl
# ...       ...                ...                        ...
# 32595    Nein       Damenfahrrad           Fahrraddiebstahl
# 32596    Nein  diverse Fahrräder  Keller- und Bodeneinbruch
# 32597    Nein            Fahrrad           Fahrraddiebstahl
# 32598    Nein      Herrenfahrrad           Fahrraddiebstahl
# 32599    Nein       Damenfahrrad           Fahrraddiebstahl
#
#                                          ERFASSUNGSGRUND
# 0            Sonstiger schwerer Diebstahl von Fahrrädern
# 1            Sonstiger schwerer Diebstahl von Fahrrädern
# 2            Sonstiger schwerer Diebstahl von Fahrrädern
# 3            Sonstiger schwerer Diebstahl von Fahrrädern
# 4                     Einfacher Diebstahl von Fahrrädern
# ...                                                  ...
# 32595        Sonstiger schwerer Diebstahl von Fahrrädern
# 32596  Sonstiger schwerer Diebstahl in/aus Keller/Bod...
# 32597                 Einfacher Diebstahl von Fahrrädern
# 32598        Sonstiger schwerer Diebstahl von Fahrrädern
# 32599        Sonstiger schwerer Diebstahl von Fahrrädern
#
# [32600 rows x 11 columns]

# %% [markdown]
# ### Preprocesing raw data
# - Change columns name
# -  Merging data category

# %% [markdown]
# #### Change columns names

# %%
df.columns = ["Record_date", "Stealing_date", "Stealing_hour", "Report_stealing_date",
              "Report_stealing_hour", "Berlin_code_area", "Bike_value", "Unsuccesful_attempt",
              "Bike_type", "Crime_type", "Crime_reason"]

# %% [markdown]
# #### Change data category in *Unsuccesful_attempt* for three categories

# %%
df["Unsuccesful_attempt"].replace({'Nein' : 'No', 'Ja' : 'Yes', 'Unbekannt' : 'Unknown'}, inplace=True)

# %% [markdown]
# #### Merge two category *Fahrrad* and *diverse Fahrrader* from *Bike_type* column as one category *Bike*

# %%
df["Bike_type"].replace({"Herrenfahrrad" : "Men", "Damenfahrrad" : "Women", "Fahrrad" : "Bike", 
                         "Mountainbike" : "Mountain", "Kinderfahrrad" : "Child", 
                         "diverse Fahrräder" : "Bike", "Rennrad" : "Racing", "Lastenfahrrad" : "Cargo"}, inplace=True)

# %% [markdown]
# #### Change column *Crime_type* vales

# %%
df["Crime_type"].replace(to_replace=["Fahrraddiebstahl", "Keller- und Bodeneinbruch"], 
                         value=["Theft", "Break-in"], inplace=True)

# %% [markdown]
# #### Change type of category *Crime_reason*
# #### Category *aggrevated theft* = theft with break-in, theft with robbery (aggresor has to use force)

# %%
df["Crime_reason"].replace(to_replace=["Sonstiger schwerer Diebstahl von Fahrrädern", 
                                       "Einfacher Diebstahl von Fahrrädern",
                                       "Sonstiger schwerer Diebstahl in/aus Keller/Boden von Fahrrädern", 
                                       "Einfacher Diebstahl aus Keller/Boden von Fahrrädern"],
                           value=["Aggravated theft", "Theft", "Aggravated theft from basement/floor", 
                                  "Theft from basement/floor"], inplace=True)

# %% [markdown]
# #### Changing column *Record_date* type from object to datetime format

# %%
df['Record_date'] = pd.to_datetime(df['Record_date'], dayfirst= True)

# %% [markdown]
# #### Create support column *date2* for next step spliting

# %%
df['date2'] = pd.to_datetime(df['Record_date'], dayfirst= True)

# %% [markdown]
# #### Create three new columns with: day, month and year

# %%
df['Record_day'] = df['date2'].dt.day
                                    
df['Record_month'] = df['date2'].dt.month

df['Record_year'] = df['date2'].dt.year

# %% [markdown]
# #### Moving three new columns for secound, third and fourth position in DataFrame

# %%
col_to_move = df.pop('Record_day')
col_to_move_1 = df.pop('Record_month')
col_to_move_2 = df.pop('Record_year')

df.insert(1, 'Record_day', col_to_move)
df.insert(2, 'Record_month', col_to_move_1)
df.insert(3, 'Record_year', col_to_move_2)

# %% [markdown]
# #### Changing *Stealing_date* type from object to datetime format

# %%
df['Stealing_date'] = pd.to_datetime(df['Stealing_date'], dayfirst= True)

# %% [markdown]
# #### Changing *Stealing_date* type from object to datetime format

# %%
df['Report_stealing_date'] = pd.to_datetime(df['Report_stealing_date'], dayfirst= True)

# %% [markdown]
# #### Change format into two columns (*Report_stealing_hour'*, *Stealing_hour*) from object to datetime hour format

# %%
df['Stealing_hour'] = pd.to_datetime(df['Stealing_hour'], format='%H').dt.hour

df['Report_stealing_hour'] = pd.to_datetime(df['Report_stealing_hour'],  format='%H').dt.hour

# %% [markdown]
# #### Drop support colum *date2* from DataFrame

# %%
df.drop(['date2'], axis=1, inplace=True)

# %% [markdown]
# #### Display new DataFrame

# %%
df
# Out:
#       Record_date  Record_day  Record_month  Record_year Stealing_date  \
# 0      2022-08-10          10             8         2022    2022-08-10
# 1      2022-08-10          10             8         2022    2022-08-09
# 2      2022-08-10          10             8         2022    2022-08-09
# 3      2022-08-10          10             8         2022    2022-08-08
# 4      2022-08-10          10             8         2022    2022-08-09
# ...           ...         ...           ...          ...           ...
# 32595  2021-01-02           2             1         2021    2021-01-01
# 32596  2021-01-01           1             1         2021    2021-01-01
# 32597  2021-01-01           1             1         2021    2021-01-01
# 32598  2021-01-01           1             1         2021    2021-01-01
# 32599  2021-01-01           1             1         2021    2021-01-01
#
#        Stealing_hour Report_stealing_date  Report_stealing_hour  \
# 0                  0           2022-08-10                     0
# 1                 15           2022-08-10                     0
# 2                 15           2022-08-10                     6
# 3                 20           2022-08-09                    12
# 4                 14           2022-08-09                    14
# ...              ...                  ...                   ...
# 32595             12           2021-01-02                    15
# 32596              5           2021-01-01                     8
# 32597             17           2021-01-01                    18
# 32598             20           2021-01-01                    20
# 32599              9           2021-01-01                    11
#
#        Berlin_code_area  Bike_value Unsuccesful_attempt Bike_type Crime_type  \
# 0               3400619         300                  No  Mountain      Theft
# 1               7601544         800                  No       Men      Theft
# 2               5100211         212                  No       Men      Theft
# 3               3601449         600                  No     Women      Theft
# 4               3601450         499                  No       Men      Theft
# ...                 ...         ...                 ...       ...        ...
# 32595          11300826         377                  No     Women      Theft
# 32596          10400941        2527                  No      Bike   Break-in
# 32597           8401241         888                  No      Bike      Theft
# 32598           2100104        2800                  No       Men      Theft
# 32599           4200206         290                  No     Women      Theft
#
#                                Crime_reason
# 0                          Aggravated theft
# 1                          Aggravated theft
# 2                          Aggravated theft
# 3                          Aggravated theft
# 4                                     Theft
# ...                                     ...
# 32595                      Aggravated theft
# 32596  Aggravated theft from basement/floor
# 32597                                 Theft
# 32598                      Aggravated theft
# 32599                      Aggravated theft
#
# [32600 rows x 14 columns]

# %% [markdown]
# #### Load csv file with LOR (Lebensweltlich orientierte Räume (LOR) = Spatial Planning Unit for Berlin)
# #### The dataset was prepared in advance. File contain columns:
# - *Berlin_code_area*
# - *Administrative_district*
# - *District*
# - *Quater*
# - *Street_name*

# %% [markdown]
# #### Load data about LOR (Lebensweltlich orientierte Räume (LOR) = Spatial Planning Unit

# %%
url = r"https://raw.githubusercontent.com/MSI17819/Berlin_bike_theft_prediction/main/Berlin_LOR_code.csv"

df_region = pd.read_csv(url, sep=';', encoding="ISO-8859-2")

df_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Berlin_code_area         540 non-null    int64
#  1   Administrative_district  540 non-null    object
#  2   District                 540 non-null    object
#  3   Quarter                  540 non-null    object
#  4   Street_name              540 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 21.2+ KB

# %% [markdown]
# #### Join two data frame (*left join*) with prepared data and LOR dataset

# %%
df_merge = pd.merge(df, df_region, how='left', on='Berlin_code_area')

# %% [markdown]
# #### Inspection DataFrame after merging two datasets

# %%
df_merge
# Out:
#       Record_date  Record_day  Record_month  Record_year Stealing_date  \
# 0      2022-08-10          10             8         2022    2022-08-10
# 1      2022-08-10          10             8         2022    2022-08-09
# 2      2022-08-10          10             8         2022    2022-08-09
# 3      2022-08-10          10             8         2022    2022-08-08
# 4      2022-08-10          10             8         2022    2022-08-09
# ...           ...         ...           ...          ...           ...
# 32595  2021-01-02           2             1         2021    2021-01-01
# 32596  2021-01-01           1             1         2021    2021-01-01
# 32597  2021-01-01           1             1         2021    2021-01-01
# 32598  2021-01-01           1             1         2021    2021-01-01
# 32599  2021-01-01           1             1         2021    2021-01-01
#
#        Stealing_hour Report_stealing_date  Report_stealing_hour  \
# 0                  0           2022-08-10                     0
# 1                 15           2022-08-10                     0
# 2                 15           2022-08-10                     6
# 3                 20           2022-08-09                    12
# 4                 14           2022-08-09                    14
# ...              ...                  ...                   ...
# 32595             12           2021-01-02                    15
# 32596              5           2021-01-01                     8
# 32597             17           2021-01-01                    18
# 32598             20           2021-01-01                    20
# 32599              9           2021-01-01                    11
#
#        Berlin_code_area  Bike_value Unsuccesful_attempt Bike_type Crime_type  \
# 0               3400619         300                  No  Mountain      Theft
# 1               7601544         800                  No       Men      Theft
# 2               5100211         212                  No       Men      Theft
# 3               3601449         600                  No     Women      Theft
# 4               3601450         499                  No       Men      Theft
# ...                 ...         ...                 ...       ...        ...
# 32595          11300826         377                  No     Women      Theft
# 32596          10400941        2527                  No      Bike   Break-in
# 32597           8401241         888                  No      Bike      Theft
# 32598           2100104        2800                  No       Men      Theft
# 32599           4200206         290                  No     Women      Theft
#
#                                Crime_reason     Administrative_district  \
# 0                          Aggravated theft                      Pankow
# 1                          Aggravated theft        Tempelhof-Schöneberg
# 2                          Aggravated theft                     Spandau
# 3                          Aggravated theft                      Pankow
# 4                                     Theft                      Pankow
# ...                                     ...                         ...
# 32595                      Aggravated theft                 Lichtenberg
# 32596  Aggravated theft from basement/floor         Marzahn-Hellersdorf
# 32597                                 Theft                    Neukölln
# 32598                      Aggravated theft    Friedrichshain-Kreuzberg
# 32599                      Aggravated theft  Charlottenburg-Wilmersdorf
#
#                          District                          Quarter  \
# 0                Südliches Pankow  Schönholz/Wilhelmsruh/Rosenthal
# 1       Marienfelde / Lichtenrade                  Lichtenrade Süd
# 2            Spandau Mitte / Nord               Falkenhagener Feld
# 3      Nördlicher Prenzlauer Berg              Prenzlauer Berg Ost
# 4      Nördlicher Prenzlauer Berg              Prenzlauer Berg Ost
# ...                           ...                              ...
# 32595            Lichtenberg Nord            Frankfurter Allee Süd
# 32596         Kaulsdorf/Mahlsdorf                        Mahlsdorf
# 32597           Buckow Nord/Rudow                            Rudow
# 32598              Kreuzberg Nord          Südliche Friedrichstadt
# 32599         Charlottenburg West                       Heerstraße
#
#                      Street_name
# 0                    Wilhelmsruh
# 1              John-Locke-Straße
# 2                   An der Kappe
# 3             Michelangelostraße
# 4      Volkspark Prenzlauer Berg
# ...                          ...
# 32595      Frankfurter Allee Süd
# 32596           Pilgramer Straße
# 32597              Blumenviertel
# 32598                Moritzplatz
# 32599                 Kranzallee
#
# [32600 rows x 18 columns]

# %% [markdown]
# ### Cleaning data

# %% [markdown]
# #### Duplicates inspection

# %%
df_merge.duplicated().value_counts()
# Out:
# False    32543
# True        57
# dtype: int64

# %% [markdown]
# #### Deleting duplicates

# %%
 df_merge.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# #### DataFrame inspection after deleting duplicated rows

# %%
df_merge.duplicated().value_counts()
# Out:
# False    32543
# dtype: int64

# %% [markdown]
# #### DataFrame inspection about missing values

# %%
df_merge.isna().sum()
# Out:
# Record_date                0
# Record_day                 0
# Record_month               0
# Record_year                0
# Stealing_date              0
# Stealing_hour              0
# Report_stealing_date       0
# Report_stealing_hour       0
# Berlin_code_area           0
# Bike_value                 0
# Unsuccesful_attempt        0
# Bike_type                  0
# Crime_type                 0
# Crime_reason               0
# Administrative_district    0
# District                   0
# Quarter                    0
# Street_name                0
# dtype: int64

# %% [markdown]
# #### Inspection about category *Unsuccesfull_attempt*

# %%
df_merge['Unsuccesful_attempt'].value_counts()
# Out:
# No         32425
# Yes          112
# Unknown        6
# Name: Unsuccesful_attempt, dtype: int64

# %% [markdown]
# #### Filter data only for those where thiefs happen and unhappen (*Unsuccesfull_attempt == No, Unsuccesfull_attempt == Yes*), exclude data with *Unknow* category.

# %%
df_merge = df_merge[(df_merge['Unsuccesful_attempt'] == 'No') | (df_merge['Unsuccesful_attempt'] == 'Yes')]

# %% [markdown]
# #### Inspection DataFrame after droping record with *Unknown* category

# %%
df_merge['Unsuccesful_attempt'].value_counts()
# Out:
# No     32425
# Yes      112
# Name: Unsuccesful_attempt, dtype: int64

# %% [markdown]
# #### Reset index and save changes

# %%
df_merge.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Dispay DataFrame

# %%
df_merge
# Out:
#       Record_date  Record_day  Record_month  Record_year Stealing_date  \
# 0      2022-08-10          10             8         2022    2022-08-10
# 1      2022-08-10          10             8         2022    2022-08-09
# 2      2022-08-10          10             8         2022    2022-08-09
# 3      2022-08-10          10             8         2022    2022-08-08
# 4      2022-08-10          10             8         2022    2022-08-09
# ...           ...         ...           ...          ...           ...
# 32532  2021-01-02           2             1         2021    2021-01-01
# 32533  2021-01-01           1             1         2021    2021-01-01
# 32534  2021-01-01           1             1         2021    2021-01-01
# 32535  2021-01-01           1             1         2021    2021-01-01
# 32536  2021-01-01           1             1         2021    2021-01-01
#
#        Stealing_hour Report_stealing_date  Report_stealing_hour  \
# 0                  0           2022-08-10                     0
# 1                 15           2022-08-10                     0
# 2                 15           2022-08-10                     6
# 3                 20           2022-08-09                    12
# 4                 14           2022-08-09                    14
# ...              ...                  ...                   ...
# 32532             12           2021-01-02                    15
# 32533              5           2021-01-01                     8
# 32534             17           2021-01-01                    18
# 32535             20           2021-01-01                    20
# 32536              9           2021-01-01                    11
#
#        Berlin_code_area  Bike_value Unsuccesful_attempt Bike_type Crime_type  \
# 0               3400619         300                  No  Mountain      Theft
# 1               7601544         800                  No       Men      Theft
# 2               5100211         212                  No       Men      Theft
# 3               3601449         600                  No     Women      Theft
# 4               3601450         499                  No       Men      Theft
# ...                 ...         ...                 ...       ...        ...
# 32532          11300826         377                  No     Women      Theft
# 32533          10400941        2527                  No      Bike   Break-in
# 32534           8401241         888                  No      Bike      Theft
# 32535           2100104        2800                  No       Men      Theft
# 32536           4200206         290                  No     Women      Theft
#
#                                Crime_reason     Administrative_district  \
# 0                          Aggravated theft                      Pankow
# 1                          Aggravated theft        Tempelhof-Schöneberg
# 2                          Aggravated theft                     Spandau
# 3                          Aggravated theft                      Pankow
# 4                                     Theft                      Pankow
# ...                                     ...                         ...
# 32532                      Aggravated theft                 Lichtenberg
# 32533  Aggravated theft from basement/floor         Marzahn-Hellersdorf
# 32534                                 Theft                    Neukölln
# 32535                      Aggravated theft    Friedrichshain-Kreuzberg
# 32536                      Aggravated theft  Charlottenburg-Wilmersdorf
#
#                          District                          Quarter  \
# 0                Südliches Pankow  Schönholz/Wilhelmsruh/Rosenthal
# 1       Marienfelde / Lichtenrade                  Lichtenrade Süd
# 2            Spandau Mitte / Nord               Falkenhagener Feld
# 3      Nördlicher Prenzlauer Berg              Prenzlauer Berg Ost
# 4      Nördlicher Prenzlauer Berg              Prenzlauer Berg Ost
# ...                           ...                              ...
# 32532            Lichtenberg Nord            Frankfurter Allee Süd
# 32533         Kaulsdorf/Mahlsdorf                        Mahlsdorf
# 32534           Buckow Nord/Rudow                            Rudow
# 32535              Kreuzberg Nord          Südliche Friedrichstadt
# 32536         Charlottenburg West                       Heerstraße
#
#                      Street_name
# 0                    Wilhelmsruh
# 1              John-Locke-Straße
# 2                   An der Kappe
# 3             Michelangelostraße
# 4      Volkspark Prenzlauer Berg
# ...                          ...
# 32532      Frankfurter Allee Süd
# 32533           Pilgramer Straße
# 32534              Blumenviertel
# 32535                Moritzplatz
# 32536                 Kranzallee
#
# [32537 rows x 18 columns]

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32537 entries, 0 to 32536
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Record_date              32537 non-null  datetime64[ns]
#  1   Record_day               32537 non-null  int64
#  2   Record_month             32537 non-null  int64
#  3   Record_year              32537 non-null  int64
#  4   Stealing_date            32537 non-null  datetime64[ns]
#  5   Stealing_hour            32537 non-null  int64
#  6   Report_stealing_date     32537 non-null  datetime64[ns]
#  7   Report_stealing_hour     32537 non-null  int64
#  8   Berlin_code_area         32537 non-null  int64
#  9   Bike_value               32537 non-null  int64
#  10  Unsuccesful_attempt      32537 non-null  object
#  11  Bike_type                32537 non-null  object
#  12  Crime_type               32537 non-null  object
#  13  Crime_reason             32537 non-null  object
#  14  Administrative_district  32537 non-null  object
#  15  District                 32537 non-null  object
#  16  Quarter                  32537 non-null  object
#  17  Street_name              32537 non-null  object
# dtypes: datetime64[ns](3), int64(7), object(8)
# memory usage: 4.5+ MB

# %% [markdown]
# #### Export DataFrame to csv file for future prediction analysis

# %%
df_merge.to_csv(r'C:\Users\dell\Desktop\Project\Berlin_bike_theft_prediction\Berlin_bike_thief_file_for_analysis.csv', 
                sep=',', encoding='utf-8', header=True, index=False)
