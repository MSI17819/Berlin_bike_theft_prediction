# %% [markdown]
# ### Import packages

# %%
import numpy as np
import pandas as pd
import requests as requests
from io import StringIO
import csv
import os
from datetime import datetime
import pytz
from time import time
import matplotlib.pyplot as plt

# %% [markdown]
# ### Prepering raw dataset for analysis
# #### All information about dataset you can find in [README.MD](https://github.com/MSI17819/Berlin_bike_theft_prediction/blob/main/README.md) file

# %% [markdown]
# #### Create empty dataframe

# %%
df = pd.DataFrame()

# %% [markdown]
# #### Data pulling function from url adress, where we can find data about Berlin bikes thief record from 01/01/2021-up to today.
# #### The data are updated everyday or at least once a two/three day, so when we run function the data are expanding on new records.

# %%
def data_pulling_function():
    global df
    url = "https://www.internetwache-polizei-berlin.de/vdb/Fahrraddiebstahl.csv"
    response = requests.get(url)
    df_raw = pd.read_csv(StringIO(response.text))
    local_time = datetime.now(pytz.timezone('Europe/Warsaw'))
    df = df.append(df_raw)
    pd.set_option('display.max_columns', None)
    print('Data update - {}'.format(local_time.strftime("%Y-%m-%d %H:%M:%S")))
    return df

data_pulling_function()
# Out:
# Data update - 2022-07-27 15:26:23
# C:\Users\dell\AppData\Local\Temp/ipykernel_7480/789137709.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_raw)
#       ANGELEGT_AM TATZEIT_ANFANG_DATUM  TATZEIT_ANFANG_STUNDE  \
# 0      26.07.2022           25.07.2022                     19
# 1      26.07.2022           26.07.2022                      9
# 2      26.07.2022           25.07.2022                     19
# 3      26.07.2022           26.07.2022                     11
# 4      26.07.2022           26.07.2022                     10
# ...           ...                  ...                    ...
# 31602  02.01.2021           01.01.2021                      1
# 31603  01.01.2021           01.01.2021                      5
# 31604  01.01.2021           01.01.2021                     20
# 31605  01.01.2021           01.01.2021                     17
# 31606  01.01.2021           01.01.2021                      9
#
#       TATZEIT_ENDE_DATUM  TATZEIT_ENDE_STUNDE       LOR  SCHADENSHOEHE  \
# 0             26.07.2022                    9  10300733           1187
# 1             26.07.2022                   10   7400928           2300
# 2             26.07.2022                   11   4501149            749
# 3             26.07.2022                   11   9501939            600
# 4             26.07.2022                   12   3601243           1099
# ...                  ...                  ...       ...            ...
# 31602         01.01.2021                    3   2100105           2000
# 31603         01.01.2021                    8  10400941           2527
# 31604         01.01.2021                   20   2100104           2800
# 31605         01.01.2021                   18   8401241            888
# 31606         01.01.2021                   11   4200206            290
#
#       VERSUCH   ART_DES_FAHRRADS                     DELIKT  \
# 0        Nein      Herrenfahrrad           Fahrraddiebstahl
# 1        Nein  diverse Fahrräder           Fahrraddiebstahl
# 2        Nein       Damenfahrrad           Fahrraddiebstahl
# 3        Nein       Damenfahrrad           Fahrraddiebstahl
# 4        Nein      Herrenfahrrad           Fahrraddiebstahl
# ...       ...                ...                        ...
# 31602    Nein       Mountainbike           Fahrraddiebstahl
# 31603    Nein  diverse Fahrräder  Keller- und Bodeneinbruch
# 31604    Nein      Herrenfahrrad           Fahrraddiebstahl
# 31605    Nein            Fahrrad           Fahrraddiebstahl
# 31606    Nein       Damenfahrrad           Fahrraddiebstahl
#
#                                          ERFASSUNGSGRUND
# 0            Sonstiger schwerer Diebstahl von Fahrrädern
# 1            Sonstiger schwerer Diebstahl von Fahrrädern
# 2            Sonstiger schwerer Diebstahl von Fahrrädern
# 3            Sonstiger schwerer Diebstahl von Fahrrädern
# 4            Sonstiger schwerer Diebstahl von Fahrrädern
# ...                                                  ...
# 31602        Sonstiger schwerer Diebstahl von Fahrrädern
# 31603  Sonstiger schwerer Diebstahl in/aus Keller/Bod...
# 31604        Sonstiger schwerer Diebstahl von Fahrrädern
# 31605                 Einfacher Diebstahl von Fahrrädern
# 31606        Sonstiger schwerer Diebstahl von Fahrrädern
#
# [31607 rows x 11 columns]

# %% [markdown]
# ### Preprocesing raw data
# - Change columns name
# -  Merging data category

# %% [markdown]
# #### Change columns names

# %%
df.columns = ["Record_date", "Stealing_date", "Stealing_hour", "Report_stealing_date",
              "Report_stealing_hour", "Berlin_code_area", "Bike_value", "Unsuccesful_attempt",
              "Bike_type", "Crime_type", "Crime_reason"]

# %% [markdown]
# #### Change data category in *Unsuccesful_attempt* for three categories

# %%
df["Unsuccesful_attempt"].replace({'Nein' : 'No', 'Ja' : 'Yes', 'Unbekannt' : 'Unknown'}, inplace=True)

# %% [markdown]
# #### Merge two category *Fahrrad* and *diverse Fahrrader* from *Bike_type* column as one category *Bike*

# %%
df["Bike_type"].replace({"Herrenfahrrad" : "Men", "Damenfahrrad" : "Women", "Fahrrad" : "Bike", 
                         "Mountainbike" : "Mountain", "Kinderfahrrad" : "Child", 
                         "diverse Fahrräder" : "Bike", "Rennrad" : "Racing", "Lastenfahrrad" : "Cargo"}, inplace=True)

# %% [markdown]
# #### Change column *Crime_type* vales

# %%
df["Crime_type"].replace(to_replace=["Fahrraddiebstahl", "Keller- und Bodeneinbruch"], 
                         value=["Theft", "Break-in"], inplace=True)

# %% [markdown]
# #### Change type of category *Crime_reason*
# #### Category *aggrevated theft* = theft with break-in, theft with robbery (aggresor has to use force)

# %%
df["Crime_reason"].replace(to_replace=["Sonstiger schwerer Diebstahl von Fahrrädern", 
                                       "Einfacher Diebstahl von Fahrrädern",
                                       "Sonstiger schwerer Diebstahl in/aus Keller/Boden von Fahrrädern", 
                                       "Einfacher Diebstahl aus Keller/Boden von Fahrrädern"],
                           value=["Aggravated theft", "Theft", "Aggravated theft from basement/floor", 
                                  "Theft from basement/floor"], inplace=True)

# %% [markdown]
# #### Changing type of data for date and create seperate columns for day, month, year

# %% [markdown]
# #### Changing column *Record_date* type from object to datetime format

# %%
df['Record_date'] = pd.to_datetime(df['Record_date'], dayfirst= True)

# %% [markdown]
# #### Create support column *date2* for next step spliting

# %%
df['date2'] = pd.to_datetime(df['Record_date'], dayfirst= True)

# %% [markdown]
# #### Create three new columns with: day, month and year

# %%
df['Record_day'] = df['date2'].dt.day
                                    
df['Record_month'] = df['date2'].dt.month

df['Record_year'] = df['date2'].dt.year

# %% [markdown]
# #### Moving three new columns for secound, third and fourth position in DataFrame

# %%
col_to_move = df.pop('Record_day')
col_to_move_1 = df.pop('Record_month')
col_to_move_2 = df.pop('Record_year')

df.insert(1, 'Record_day', col_to_move)
df.insert(2, 'Record_month', col_to_move_1)
df.insert(3, 'Record_year', col_to_move_2)

# %% [markdown]
# #### Changing *Stealing_date* type from object to datetime format

# %%
df['Stealing_date'] = pd.to_datetime(df['Stealing_date'], dayfirst= True)

# %% [markdown]
# #### Changing *Stealing_date* type from object to datetime format

# %%
df['Report_stealing_date'] = pd.to_datetime(df['Report_stealing_date'], dayfirst= True)

# %% [markdown]
# #### Change format into two columns (*Report_stealing_hour'*, *Stealing_hour*) from object to datetime hour format

# %%
df['Stealing_hour'] = pd.to_datetime(df['Stealing_hour'], format='%H').dt.hour

df['Report_stealing_hour'] = pd.to_datetime(df['Report_stealing_hour'],  format='%H').dt.hour

# %% [markdown]
# #### Drop support colum *date2* from DataFrame

# %%
df.drop(['date2'], axis=1, inplace=True)

# %% [markdown]
# #### Display new DataFrame

# %%
df
# Out:
#       Record_date  Record_day  Record_month  Record_year Stealing_date  \
# 0      2022-07-26          26             7         2022    2022-07-25
# 1      2022-07-26          26             7         2022    2022-07-26
# 2      2022-07-26          26             7         2022    2022-07-25
# 3      2022-07-26          26             7         2022    2022-07-26
# 4      2022-07-26          26             7         2022    2022-07-26
# ...           ...         ...           ...          ...           ...
# 31602  2021-01-02           2             1         2021    2021-01-01
# 31603  2021-01-01           1             1         2021    2021-01-01
# 31604  2021-01-01           1             1         2021    2021-01-01
# 31605  2021-01-01           1             1         2021    2021-01-01
# 31606  2021-01-01           1             1         2021    2021-01-01
#
#        Stealing_hour Report_stealing_date  Report_stealing_hour  \
# 0                 19           2022-07-26                     9
# 1                  9           2022-07-26                    10
# 2                 19           2022-07-26                    11
# 3                 11           2022-07-26                    11
# 4                 10           2022-07-26                    12
# ...              ...                  ...                   ...
# 31602              1           2021-01-01                     3
# 31603              5           2021-01-01                     8
# 31604             20           2021-01-01                    20
# 31605             17           2021-01-01                    18
# 31606              9           2021-01-01                    11
#
#        Berlin_code_area  Bike_value Unsuccesful_attempt Bike_type Crime_type  \
# 0              10300733        1187                  No       Men      Theft
# 1               7400928        2300                  No      Bike      Theft
# 2               4501149         749                  No     Women      Theft
# 3               9501939         600                  No     Women      Theft
# 4               3601243        1099                  No       Men      Theft
# ...                 ...         ...                 ...       ...        ...
# 31602           2100105        2000                  No  Mountain      Theft
# 31603          10400941        2527                  No      Bike   Break-in
# 31604           2100104        2800                  No       Men      Theft
# 31605           8401241         888                  No      Bike      Theft
# 31606           4200206         290                  No     Women      Theft
#
#                                Crime_reason
# 0                          Aggravated theft
# 1                          Aggravated theft
# 2                          Aggravated theft
# 3                          Aggravated theft
# 4                          Aggravated theft
# ...                                     ...
# 31602                      Aggravated theft
# 31603  Aggravated theft from basement/floor
# 31604                      Aggravated theft
# 31605                                 Theft
# 31606                      Aggravated theft
#
# [31607 rows x 14 columns]

# %% [markdown]
# #### Load csv file with LOR (Lebensweltlich orientierte Räume (LOR) = Spatial Planning Unit for Berlin)
# #### The dataset was prepared in advance. File contain columns:
# - *Berlin_code_area*
# - *Administrative_district*
# - *District*
# - *Quater*
# - *Street_name*

# %% [markdown]
# #### Load data about LOR (Lebensweltlich orientierte Räume (LOR) = Spatial Planning Unit

# %%
url = r"https://raw.githubusercontent.com/MSI17819/Berlin_bike_theft_prediction/main/Berlin_LOR_code.csv"

df_region = pd.read_csv(url, sep=';', encoding="ISO-8859-2")

df_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Berlin_code_area         540 non-null    int64
#  1   Administrative_district  540 non-null    object
#  2   District                 540 non-null    object
#  3   Quarter                  540 non-null    object
#  4   Street_name              540 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 21.2+ KB

# %% [markdown]
# #### Join two data frame (*left join*) with prepared data and LOR dataset

# %%
df_merge = pd.merge(df, df_region, how='left', on='Berlin_code_area')

# %% [markdown]
# #### Inspection DataFrame after merging two datasets

# %%
df_merge
# Out:
#       Record_date  Record_day  Record_month  Record_year Stealing_date  \
# 0      2022-07-26          26             7         2022    2022-07-25
# 1      2022-07-26          26             7         2022    2022-07-26
# 2      2022-07-26          26             7         2022    2022-07-25
# 3      2022-07-26          26             7         2022    2022-07-26
# 4      2022-07-26          26             7         2022    2022-07-26
# ...           ...         ...           ...          ...           ...
# 31602  2021-01-02           2             1         2021    2021-01-01
# 31603  2021-01-01           1             1         2021    2021-01-01
# 31604  2021-01-01           1             1         2021    2021-01-01
# 31605  2021-01-01           1             1         2021    2021-01-01
# 31606  2021-01-01           1             1         2021    2021-01-01
#
#        Stealing_hour Report_stealing_date  Report_stealing_hour  \
# 0                 19           2022-07-26                     9
# 1                  9           2022-07-26                    10
# 2                 19           2022-07-26                    11
# 3                 11           2022-07-26                    11
# 4                 10           2022-07-26                    12
# ...              ...                  ...                   ...
# 31602              1           2021-01-01                     3
# 31603              5           2021-01-01                     8
# 31604             20           2021-01-01                    20
# 31605             17           2021-01-01                    18
# 31606              9           2021-01-01                    11
#
#        Berlin_code_area  Bike_value Unsuccesful_attempt Bike_type Crime_type  \
# 0              10300733        1187                  No       Men      Theft
# 1               7400928        2300                  No      Bike      Theft
# 2               4501149         749                  No     Women      Theft
# 3               9501939         600                  No     Women      Theft
# 4               3601243        1099                  No       Men      Theft
# ...                 ...         ...                 ...       ...        ...
# 31602           2100105        2000                  No  Mountain      Theft
# 31603          10400941        2527                  No      Bike   Break-in
# 31604           2100104        2800                  No       Men      Theft
# 31605           8401241         888                  No      Bike      Theft
# 31606           4200206         290                  No     Women      Theft
#
#                                Crime_reason     Administrative_district  \
# 0                          Aggravated theft         Marzahn-Hellersdorf
# 1                          Aggravated theft        Tempelhof-Schöneberg
# 2                          Aggravated theft  Charlottenburg-Wilmersdorf
# 3                          Aggravated theft            Treptow-Köpenick
# 4                          Aggravated theft                      Pankow
# ...                                     ...                         ...
# 31602                      Aggravated theft    Friedrichshain-Kreuzberg
# 31603  Aggravated theft from basement/floor         Marzahn-Hellersdorf
# 31604                      Aggravated theft    Friedrichshain-Kreuzberg
# 31605                                 Theft                    Neukölln
# 31606                      Aggravated theft  Charlottenburg-Wilmersdorf
#
#                          District                  Quarter         Street_name
# 0                        Biesdorf                 Biesdorf        Alt-Biesdorf
# 1                       Tempelhof         Tempelhof Südost      Germaniagarten
# 2             Wilmersdorf Zentrum    Volkspark Wilmersdorf  Nikolsburger Platz
# 3              Treptow-Köpenick 5             Dammvorstadt       Bahnhofstraße
# 4      Nördlicher Prenzlauer Berg     Prenzlauer Berg Nord     Rodenbergstraße
# ...                           ...                      ...                 ...
# 31602              Kreuzberg Nord  Südliche Friedrichstadt       Prinzenstraße
# 31603         Kaulsdorf/Mahlsdorf                Mahlsdorf    Pilgramer Straße
# 31604              Kreuzberg Nord  Südliche Friedrichstadt         Moritzplatz
# 31605           Buckow Nord/Rudow                    Rudow       Blumenviertel
# 31606         Charlottenburg West               Heerstraße          Kranzallee
#
# [31607 rows x 18 columns]

# %% [markdown]
# ### Cleaning data

# %% [markdown]
# #### Duplicates inspection

# %%
df_merge.duplicated().value_counts()
# Out:
# False    31551
# True        56
# dtype: int64

# %% [markdown]
# #### Deleting duplicates

# %%
 df_merge.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# #### DataFrame inspection after deleting duplicated rows

# %%
df_merge.duplicated().value_counts()
# Out:
# False    31551
# dtype: int64

# %% [markdown]
# #### DataFrame inspection about missing values

# %%
df_merge.isna().sum()
# Out:
# Record_date                0
# Record_day                 0
# Record_month               0
# Record_year                0
# Stealing_date              0
# Stealing_hour              0
# Report_stealing_date       0
# Report_stealing_hour       0
# Berlin_code_area           0
# Bike_value                 0
# Unsuccesful_attempt        0
# Bike_type                  0
# Crime_type                 0
# Crime_reason               0
# Administrative_district    0
# District                   0
# Quarter                    0
# Street_name                0
# dtype: int64

# %% [markdown]
# #### Inspection about category *Unsuccesfull_attempt*

# %%
df_merge['Unsuccesful_attempt'].value_counts()
# Out:
# No         31439
# Yes          107
# Unknown        5
# Name: Unsuccesful_attempt, dtype: int64

# %% [markdown]
# #### Filter data only for those where thiefs happen and unhappen (*Unsuccesfull_attempt == No, Unsuccesfull_attempt == Yes*), exclude data with *Unknow* category.

# %%
df_merge = df_merge[(df_merge['Unsuccesful_attempt'] == 'No') | (df_merge['Unsuccesful_attempt'] == 'Yes')]

# %% [markdown]
# #### Inspection DataFrame after droping record with *Unknown* category

# %%
df_merge['Unsuccesful_attempt'].value_counts()
# Out:
# No     31439
# Yes      107
# Name: Unsuccesful_attempt, dtype: int64

# %% [markdown]
# #### Reset index and save changes

# %%
df_merge.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Dispay DataFrame

# %%
df_merge
# Out:
#       Record_date  Record_day  Record_month  Record_year Stealing_date  \
# 0      2022-07-26          26             7         2022    2022-07-25
# 1      2022-07-26          26             7         2022    2022-07-26
# 2      2022-07-26          26             7         2022    2022-07-25
# 3      2022-07-26          26             7         2022    2022-07-26
# 4      2022-07-26          26             7         2022    2022-07-26
# ...           ...         ...           ...          ...           ...
# 31541  2021-01-02           2             1         2021    2021-01-01
# 31542  2021-01-01           1             1         2021    2021-01-01
# 31543  2021-01-01           1             1         2021    2021-01-01
# 31544  2021-01-01           1             1         2021    2021-01-01
# 31545  2021-01-01           1             1         2021    2021-01-01
#
#        Stealing_hour Report_stealing_date  Report_stealing_hour  \
# 0                 19           2022-07-26                     9
# 1                  9           2022-07-26                    10
# 2                 19           2022-07-26                    11
# 3                 11           2022-07-26                    11
# 4                 10           2022-07-26                    12
# ...              ...                  ...                   ...
# 31541              1           2021-01-01                     3
# 31542              5           2021-01-01                     8
# 31543             20           2021-01-01                    20
# 31544             17           2021-01-01                    18
# 31545              9           2021-01-01                    11
#
#        Berlin_code_area  Bike_value Unsuccesful_attempt Bike_type Crime_type  \
# 0              10300733        1187                  No       Men      Theft
# 1               7400928        2300                  No      Bike      Theft
# 2               4501149         749                  No     Women      Theft
# 3               9501939         600                  No     Women      Theft
# 4               3601243        1099                  No       Men      Theft
# ...                 ...         ...                 ...       ...        ...
# 31541           2100105        2000                  No  Mountain      Theft
# 31542          10400941        2527                  No      Bike   Break-in
# 31543           2100104        2800                  No       Men      Theft
# 31544           8401241         888                  No      Bike      Theft
# 31545           4200206         290                  No     Women      Theft
#
#                                Crime_reason     Administrative_district  \
# 0                          Aggravated theft         Marzahn-Hellersdorf
# 1                          Aggravated theft        Tempelhof-Schöneberg
# 2                          Aggravated theft  Charlottenburg-Wilmersdorf
# 3                          Aggravated theft            Treptow-Köpenick
# 4                          Aggravated theft                      Pankow
# ...                                     ...                         ...
# 31541                      Aggravated theft    Friedrichshain-Kreuzberg
# 31542  Aggravated theft from basement/floor         Marzahn-Hellersdorf
# 31543                      Aggravated theft    Friedrichshain-Kreuzberg
# 31544                                 Theft                    Neukölln
# 31545                      Aggravated theft  Charlottenburg-Wilmersdorf
#
#                          District                  Quarter         Street_name
# 0                        Biesdorf                 Biesdorf        Alt-Biesdorf
# 1                       Tempelhof         Tempelhof Südost      Germaniagarten
# 2             Wilmersdorf Zentrum    Volkspark Wilmersdorf  Nikolsburger Platz
# 3              Treptow-Köpenick 5             Dammvorstadt       Bahnhofstraße
# 4      Nördlicher Prenzlauer Berg     Prenzlauer Berg Nord     Rodenbergstraße
# ...                           ...                      ...                 ...
# 31541              Kreuzberg Nord  Südliche Friedrichstadt       Prinzenstraße
# 31542         Kaulsdorf/Mahlsdorf                Mahlsdorf    Pilgramer Straße
# 31543              Kreuzberg Nord  Südliche Friedrichstadt         Moritzplatz
# 31544           Buckow Nord/Rudow                    Rudow       Blumenviertel
# 31545         Charlottenburg West               Heerstraße          Kranzallee
#
# [31546 rows x 18 columns]

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31546 entries, 0 to 31545
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Record_date              31546 non-null  datetime64[ns]
#  1   Record_day               31546 non-null  int64
#  2   Record_month             31546 non-null  int64
#  3   Record_year              31546 non-null  int64
#  4   Stealing_date            31546 non-null  datetime64[ns]
#  5   Stealing_hour            31546 non-null  int64
#  6   Report_stealing_date     31546 non-null  datetime64[ns]
#  7   Report_stealing_hour     31546 non-null  int64
#  8   Berlin_code_area         31546 non-null  int64
#  9   Bike_value               31546 non-null  int64
#  10  Unsuccesful_attempt      31546 non-null  object
#  11  Bike_type                31546 non-null  object
#  12  Crime_type               31546 non-null  object
#  13  Crime_reason             31546 non-null  object
#  14  Administrative_district  31546 non-null  object
#  15  District                 31546 non-null  object
#  16  Quarter                  31546 non-null  object
#  17  Street_name              31546 non-null  object
# dtypes: datetime64[ns](3), int64(7), object(8)
# memory usage: 4.3+ MB

# %% [markdown]
# #### Export DataFrame to csv file for future prediction analysis

# %%
df_merge.to_csv(r'C:\Users\dell\Desktop\Berlin_bike_thief_file_for_analysis.csv', 
                sep=',', encoding='utf-8', header=True, index=False)
